# %% [markdown]
# <a href="https://colab.research.google.com/github/pitontoey/PythonDataViz2026/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/DataViz2026'

covid_file_path = os.path.join(path,'confirmed-cases.csv')
print(covid_file_path)
# Out:
# /content/drive/MyDrive/DataViz2026/confirmed-cases.csv

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid.head()
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ

# %% [markdown]
# # .isnull()?? None??

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  Notified date    sex    age  nationality  \
# 0      False          False           True  False  False        False
# 1      False          False           True  False  False        False
# 2      False          False           True  False  False        False
# 3      False          False           True  False  False        False
# 4      False          False           True  False  False        False
# ...      ...            ...            ...    ...    ...          ...
# 12648  False          False          False  False  False        False
# 12649  False          False          False  False  False        False
# 12650  False          False          False  False  False        False
# 12651  False          False          False  False  False        False
# 12652  False          False          False  False  False        False
#
#        province_of_isolation  province_of_onset  district_of_onset   risk
# 0                      False              False               True  False
# 1                      False              False               True  False
# 2                      False              False              False  False
# 3                      False              False               True  False
# 4                      False              False               True  False
# ...                      ...                ...                ...    ...
# 12648                  False              False              False  False
# 12649                  False              False              False  False
# 12650                  False              False              False  False
# 12651                  False              False              False  False
# 12652                  False              False              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# .any() เอาค่าความจริงภายในแต่ละ column มา ```OR``` กัน

# %%
data_covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# .all() เอาค่าความจริงภายในแต่ละ column มา ```AND``` กัน

# %%
data_covid.isnull().all()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# nationality              False
# province_of_isolation    False
# province_of_onset        False
# district_of_onset        False
# risk                     False
# dtype: bool

# %%
data_covid.iloc[0,0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_884/3890063426.py in <cell line: 0>()
# ----> 1 data_covid.iloc[0,0].isnull()
#
# AttributeError: 'numpy.int64' object has no attribute 'isnull'

# %%
data_covid['No.'][0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_884/531113862.py in <cell line: 0>()
# ----> 1 data_covid['No.'][0].isnull()
#
# AttributeError: 'numpy.int64' object has no attribute 'isnull'

# %%
data_covid.iloc[0,0]
# Out:
# np.int64(1)

# %%
data_covid.iloc[:1,0].isnull()
# Out:
# 0    False
# Name: No., dtype: bool

# %% [markdown]
# # ต่อตารางแกน X แกน y
#
#
# *   ต่อแกน y คือ เพิ่ม records (เพิ่มจำนวนข้อมูล)
# *   ต่อแกน x คือ เพิ่ม columns (เพิ่มรายละเอียดของข้อมูล)

# %% [markdown]
# ## ต่อแกน Y pd.concat()

# %%
data_covid['province_of_onset']=='ขอนแก่น'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
dataKK = data_covid[data_covid['province_of_onset']=='ขอนแก่น']
dataKK.head()
# Out:
#        No. announce_date Notified date   sex   age nationality  \
# 181    182       18/3/20     15/3/2020   ชาย  33.0    Thailand
# 463    464       22/3/20     21/3/2020  หญิง  36.0    Thailand
# 1467  1468       30/3/20     26/3/2020   ชาย  19.0    Thailand
# 1971  1972        3/4/20     31/3/2020  หญิง  70.0    Thailand
# 2638  2639       15/4/20     14/4/2020  หญิง  63.0    Thailand
#
#      province_of_isolation province_of_onset district_of_onset  \
# 181                ขอนแก่น           ขอนแก่น             เมือง
# 463                ขอนแก่น           ขอนแก่น             เมือง
# 1467               ขอนแก่น           ขอนแก่น             เมือง
# 1971               ขอนแก่น           ขอนแก่น             เมือง
# 2638               ขอนแก่น           ขอนแก่น            น้ำพอง
#
#                                                risk
# 181                                         สนามมวย
# 463     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                  คนไทยเดินทางกลับจากต่างประเทศ
# 1971  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                  สัมผัสผู้เดินทางจากต่างประเทศ

# %%
dataUD = data_covid[data_covid['province_of_onset']=='อุดรธานี']
dataUD.head()
# Out:
#      No. announce_date Notified date   sex   age nationality  \
# 425  426       22/3/20     21/3/2020   ชาย  33.0    Thailand
# 435  436       22/3/20     20/3/2020  หญิง  47.0    Thailand
# 472  473       22/3/20     22/3/2020  หญิง  26.0    Thailand
# 884  885       25/3/20     24/3/2020   ชาย  25.0    Thailand
# 886  887       25/3/20     24/3/2020  หญิง  20.0    Thailand
#
#     province_of_isolation province_of_onset district_of_onset  \
# 425              อุดรธานี          อุดรธานี            กุดจับ
# 435              อุดรธานี          อุดรธานี             เมือง
# 472              อุดรธานี          อุดรธานี             เมือง
# 884              อุดรธานี          อุดรธานี             เมือง
# 886              อุดรธานี          อุดรธานี             เมือง
#
#                                             risk
# 425                                      สนามมวย
# 435                                  สถานบันเทิง
# 472  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 884                                  สถานบันเทิง
# 886  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้

# %%
dataMS = data_covid[data_covid['province_of_onset']=='มหาสารคาม']
dataMS.head()
# Out:
#          No. announce_date Notified date   sex   age nationality  \
# 347      348       21/3/20     20/3/2020   ชาย  34.0    Thailand
# 790      791       24/3/20     28/3/2020   ชาย  48.0    Thailand
# 6691    6692      31/12/20    30/12/2020  หญิง  42.0    Thailand
# 10803  10804       12/1/21     11/1/2021  หญิง  25.0    Thailand
#
#       province_of_isolation province_of_onset district_of_onset  \
# 347                 นนทบุรี         มหาสารคาม          เชียงยืน
# 790               มหาสารคาม         มหาสารคาม    พยัคฆภูมิพิสัย
# 6691              มหาสารคาม         มหาสารคาม             บรบือ
# 10803             สมุทรสาคร         มหาสารคาม          วาปีปทุม
#
#                                               risk
# 347    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 790                                    สถานบันเทิง
# 6691                             Cluster สมุทรสาคร
# 10803                            Cluster สมุทรสาคร

# %%
dataMYisan = pd.concat([dataKK,dataUD,dataMS])
dataMYisan
# Out:
#          No. announce_date Notified date   sex   age  \
# 181      182       18/3/20     15/3/2020   ชาย  33.0
# 463      464       22/3/20     21/3/2020  หญิง  36.0
# 1467    1468       30/3/20     26/3/2020   ชาย  19.0
# 1971    1972        3/4/20     31/3/2020  หญิง  70.0
# 2638    2639       15/4/20     14/4/2020  หญิง  63.0
# 2674    2675       17/4/20     16/4/2020   ชาย  68.0
# 5949    5950      26/12/20    25/12/2020  หญิง  32.0
# 6083    6084      27/12/20    26/12/2020  หญิง  36.0
# 9334    9335        7/1/21      6/1/2021   ชาย  17.0
# 9335    9336        7/1/21      6/1/2021   ชาย  20.0
# 10611  10612       12/1/21     11/1/2021   ชาย  17.0
# 11518  11519       16/1/21     15/1/2021   ชาย  12.0
# 11698  11699       17/1/21     16/1/2021  หญิง  17.0
# 11699  11700       17/1/21     16/1/2021  หญิง  37.0
# 425      426       22/3/20     21/3/2020   ชาย  33.0
# 435      436       22/3/20     20/3/2020  หญิง  47.0
# 472      473       22/3/20     22/3/2020  หญิง  26.0
# 884      885       25/3/20     24/3/2020   ชาย  25.0
# 886      887       25/3/20     24/3/2020  หญิง  20.0
# 942      943       26/3/20     25/3/2020   ชาย  31.0
# 1060    1061       27/3/20     26/3/2020   ชาย  54.0
# 2014    2015        4/4/20      3/4/2020  หญิง  49.0
# 5811    5812      24/12/20    23/12/2020   ชาย  30.0
# 7434    7435        3/1/21           NaN  หญิง  66.0
# 347      348       21/3/20     20/3/2020   ชาย  34.0
# 790      791       24/3/20     28/3/2020   ชาย  48.0
# 6691    6692      31/12/20    30/12/2020  หญิง  42.0
# 10803  10804       12/1/21     11/1/2021  หญิง  25.0
#
#                     nationality province_of_isolation province_of_onset  \
# 181                    Thailand               ขอนแก่น           ขอนแก่น
# 463                    Thailand               ขอนแก่น           ขอนแก่น
# 1467                   Thailand               ขอนแก่น           ขอนแก่น
# 1971                   Thailand               ขอนแก่น           ขอนแก่น
# 2638                   Thailand               ขอนแก่น           ขอนแก่น
# 2674                   Thailand               ขอนแก่น           ขอนแก่น
# 5949                   Thailand               ขอนแก่น           ขอนแก่น
# 6083                   Thailand               ขอนแก่น           ขอนแก่น
# 9334                   Thailand               ขอนแก่น           ขอนแก่น
# 9335                   Thailand               ขอนแก่น           ขอนแก่น
# 10611                  Thailand               ขอนแก่น           ขอนแก่น
# 11518                  Thailand               ขอนแก่น           ขอนแก่น
# 11698                  Thailand               ขอนแก่น           ขอนแก่น
# 11699                  Thailand               ขอนแก่น           ขอนแก่น
# 425                    Thailand              อุดรธานี          อุดรธานี
# 435                    Thailand              อุดรธานี          อุดรธานี
# 472                    Thailand              อุดรธานี          อุดรธานี
# 884                    Thailand              อุดรธานี          อุดรธานี
# 886                    Thailand              อุดรธานี          อุดรธานี
# 942                    Thailand              อุดรธานี          อุดรธานี
# 1060   United States of America              อุดรธานี          อุดรธานี
# 2014                   Thailand              อุดรธานี          อุดรธานี
# 5811                   Thailand              อุดรธานี          อุดรธานี
# 7434                   Thailand                 ระยอง          อุดรธานี
# 347                    Thailand               นนทบุรี         มหาสารคาม
# 790                    Thailand             มหาสารคาม         มหาสารคาม
# 6691                   Thailand             มหาสารคาม         มหาสารคาม
# 10803                  Thailand             สมุทรสาคร         มหาสารคาม
#
#       district_of_onset                                           risk
# 181               เมือง                                        สนามมวย
# 463               เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467              เมือง                  คนไทยเดินทางกลับจากต่างประเทศ
# 1971              เมือง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638             น้ำพอง                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2674             น้ำพอง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5949            แวงใหญ่                              Cluster สมุทรสาคร
# 6083            แวงใหญ่                              Cluster สมุทรสาคร
# 9334              เมือง                           อยู่ระหว่างการสอบสวน
# 9335              เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10611             เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11518             เมือง                           อยู่ระหว่างการสอบสวน
# 11698             เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11699             เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 425              กุดจับ                                        สนามมวย
# 435               เมือง                                    สถานบันเทิง
# 472               เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 884               เมือง                                    สถานบันเทิง
# 886               เมือง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 942               เมือง                                    สถานบันเทิง
# 1060            บ้านดุง                  คนไทยเดินทางกลับจากต่างประเทศ
# 2014           โนนสะอาด                  คนไทยเดินทางกลับจากต่างประเทศ
# 5811              เมือง                              Cluster สมุทรสาคร
# 7434            บ้านผือ                                  Cluster ระยอง
# 347            เชียงยืน    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 790      พยัคฆภูมิพิสัย                                    สถานบันเทิง
# 6691              บรบือ                              Cluster สมุทรสาคร
# 10803          วาปีปทุม                              Cluster สมุทรสาคร

# %% [markdown]
# ## ต่อแกน X
#
#
# *   จับ 2 ตารางมาต่อกันเลย (merge)
# *   เลือกมาเพิ่มเฉพาะบาง column (map)

# %%
data_province = data_covid[['No.','announce_date','province_of_onset']]
data_province
# Out:
#          No. announce_date province_of_onset
# 0          1       12/1/20     กรุงเทพมหานคร
# 1          2       17/1/20     กรุงเทพมหานคร
# 2          3       22/1/20            นครปฐม
# 3          4       22/1/20     กรุงเทพมหานคร
# 4          5       24/1/20     กรุงเทพมหานคร
# ...      ...           ...               ...
# 12648  12649       20/1/21     กรุงเทพมหานคร
# 12649  12650       20/1/21            ชลบุรี
# 12650  12651       20/1/21             ระยอง
# 12651  12652       20/1/21             ระยอง
# 12652  12653       20/1/21             ระยอง
#
# [12653 rows x 3 columns]

# %%
data_human = data_covid[['No.','age','sex','nationality']]
data_human
# Out:
#          No.   age   sex nationality
# 0          1  61.0  หญิง       China
# 1          2  74.0  หญิง       China
# 2          3  73.0  หญิง    Thailand
# 3          4  68.0   ชาย       China
# 4          5  66.0  หญิง       China
# ...      ...   ...   ...         ...
# 12648  12649  42.0   ชาย    Thailand
# 12649  12650  44.0  หญิง    Thailand
# 12650  12651  52.0  หญิง    Thailand
# 12651  12652  23.0  หญิง    Thailand
# 12652  12653  29.0  หญิง    Thailand
#
# [12653 rows x 4 columns]

# %% [markdown]
# # แบบง่าย รู้ว่าสองตาราง record ตรงกัน

# %%
full_table1 = data_human.merge(data_province)
full_table1.head()
# Out:
#    No.   age   sex nationality announce_date province_of_onset
# 0    1  61.0  หญิง       China       12/1/20     กรุงเทพมหานคร
# 1    2  74.0  หญิง       China       17/1/20     กรุงเทพมหานคร
# 2    3  73.0  หญิง    Thailand       22/1/20            นครปฐม
# 3    4  68.0   ชาย       China       22/1/20     กรุงเทพมหานคร
# 4    5  66.0  หญิง       China       24/1/20     กรุงเทพมหานคร

# %% [markdown]
# ## sort

# %%
data_human2 = data_human.sort_values('age')
data_human2
# Out:
#          No.  age   sex nationality
# 3725    3726  1.0  หญิง    Thailand
# 3684    3685  1.0   ชาย       Burma
# 9484    9485  1.0  หญิง    Thailand
# 3571    3572  1.0   ชาย       India
# 9140    9141  1.0  หญิง    Thailand
# ...      ...  ...   ...         ...
# 11646  11647  NaN  หญิง       Burma
# 11647  11648  NaN   ชาย       Burma
# 11648  11649  NaN  หญิง       Burma
# 11649  11650  NaN   ชาย       Burma
# 11650  11651  NaN   ชาย       Burma
#
# [12653 rows x 4 columns]

# %%
full_table2 = data_human2.merge(data_province)
full_table2.head()
# Out:
#     No.  age   sex nationality announce_date province_of_onset
# 0  3726  1.0  หญิง    Thailand      23/10/20            ชลบุรี
# 1  3685  1.0   ชาย       Burma      18/10/20               ตาก
# 2  9485  1.0  หญิง    Thailand        7/1/21            ชลบุรี
# 3  3572  1.0   ชาย       India       2/10/20     กรุงเทพมหานคร
# 4  9141  1.0  หญิง    Thailand        6/1/21            ชลบุรี

# %%
data_human2_renamed = data_human2.rename(columns={'No.': 'patientNumber'})
data_human2_renamed.head()
# Out:
#       patientNumber  age   sex nationality
# 3725           3726  1.0  หญิง    Thailand
# 3684           3685  1.0   ชาย       Burma
# 9484           9485  1.0  หญิง    Thailand
# 3571           3572  1.0   ชาย       India
# 9140           9141  1.0  หญิง    Thailand

# %%
data_human2_renamed.merge(data_province)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /tmp/ipykernel_884/2133350163.py in <cell line: 0>()
# ----> 1 data_human2_renamed.merge(data_province)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     784             raise MergeError(msg)
#     785
# --> 786         self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     787
#     788         (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _validate_left_right_on(self, left_on, right_on)
#    1570                 common_cols = left_cols.intersection(right_cols)
#    1571                 if len(common_cols) == 0:
# -> 1572                     raise MergeError(
#    1573                         "No common columns to perform merge on. "
#    1574                         f"Merge options: left_on={left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
full_table3 = data_human2_renamed.merge(data_province,left_on='patientNumber',right_on='No.')
full_table3.head()
# Out:
#    patientNumber  age   sex nationality   No. announce_date province_of_onset
# 0           3726  1.0  หญิง    Thailand  3726      23/10/20            ชลบุรี
# 1           3685  1.0   ชาย       Burma  3685      18/10/20               ตาก
# 2           9485  1.0  หญิง    Thailand  9485        7/1/21            ชลบุรี
# 3           3572  1.0   ชาย       India  3572       2/10/20     กรุงเทพมหานคร
# 4           9141  1.0  หญิง    Thailand  9141        6/1/21            ชลบุรี

# %% [markdown]
# ## map() เลือกมาเฉพาะบาง column มาแปะเพิ่มเข้าไป

# %%
data_human2_renamed.head()
# Out:
#       patientNumber  age   sex nationality
# 3725           3726  1.0  หญิง    Thailand
# 3684           3685  1.0   ชาย       Burma
# 9484           9485  1.0  หญิง    Thailand
# 3571           3572  1.0   ชาย       India
# 9140           9141  1.0  หญิง    Thailand

# %%
data_covid.head()
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ

# %% [markdown]
# คุณสมบัติของ pandas ก็คือเราสามารถสร้าง column ใหม่ให้ตาราง df ได้ โดย
#
# ```df['ชื่อ column ใหม่'] = (list ที่มีจำนวนสมาชิกเท่ากับจำนวน record ของ df)```

# %%
data_human2_renamed.head()
# Out:
#       patientNumber  age   sex nationality
# 3725           3726  1.0  หญิง    Thailand
# 3684           3685  1.0   ชาย       Burma
# 9484           9485  1.0  หญิง    Thailand
# 3571           3572  1.0   ชาย       India
# 9140           9141  1.0  หญิง    Thailand

# %%
data_human2_renamed['num'] = range(data_human2_renamed.shape[0])
data_human2_renamed
# Out:
#        patientNumber  age   sex nationality    num
# 3725            3726  1.0  หญิง    Thailand      0
# 3684            3685  1.0   ชาย       Burma      1
# 9484            9485  1.0  หญิง    Thailand      2
# 3571            3572  1.0   ชาย       India      3
# 9140            9141  1.0  หญิง    Thailand      4
# ...              ...  ...   ...         ...    ...
# 11646          11647  NaN  หญิง       Burma  12648
# 11647          11648  NaN   ชาย       Burma  12649
# 11648          11649  NaN  หญิง       Burma  12650
# 11649          11650  NaN   ชาย       Burma  12651
# 11650          11651  NaN   ชาย       Burma  12652
#
# [12653 rows x 5 columns]

# %%
data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk']) #.map มันจะ ผูกค่า 'patientNumber' กับ 'No.' เข้าด้วยกัน แล้ว return list ของค่า ['risk']
# Out:
# 3725                                 State Quarantine
# 3684      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 9484      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3571     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 9140                         Cluster บ่อนพัทยา/ชลบุรี
#                              ...
# 11646                               Cluster สมุทรสาคร
# 11647                               Cluster สมุทรสาคร
# 11648                               Cluster สมุทรสาคร
# 11649                               Cluster สมุทรสาคร
# 11650                               Cluster สมุทรสาคร
# Name: patientNumber, Length: 12653, dtype: object

# %%
data_human2_renamed['detail'] = data_human2_renamed['patientNumber'].map(data_covid.set_index('No.')['risk'])
data_human2_renamed
# Out:
#        patientNumber  age   sex nationality    num  \
# 3725            3726  1.0  หญิง    Thailand      0
# 3684            3685  1.0   ชาย       Burma      1
# 9484            9485  1.0  หญิง    Thailand      2
# 3571            3572  1.0   ชาย       India      3
# 9140            9141  1.0  หญิง    Thailand      4
# ...              ...  ...   ...         ...    ...
# 11646          11647  NaN  หญิง       Burma  12648
# 11647          11648  NaN   ชาย       Burma  12649
# 11648          11649  NaN  หญิง       Burma  12650
# 11649          11650  NaN   ชาย       Burma  12651
# 11650          11651  NaN   ชาย       Burma  12652
#
#                                              detail
# 3725                               State Quarantine
# 3684    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 9484    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3571   ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 9140                       Cluster บ่อนพัทยา/ชลบุรี
# ...                                             ...
# 11646                             Cluster สมุทรสาคร
# 11647                             Cluster สมุทรสาคร
# 11648                             Cluster สมุทรสาคร
# 11649                             Cluster สมุทรสาคร
# 11650                             Cluster สมุทรสาคร
#
# [12653 rows x 6 columns]

# %% [markdown]
# ## HW7 สร้างตารางใหม่ ที่ค่าใน ```sex``` เป็น missing ทั้งหมด
# - สรุปว่าทำไม record นั้นๆถึงเป็น missing

# %% [markdown]
# * .groupby
# * create pandas table
# * simple visualization
# * save table

# %% [markdown]
# **สรุปว่าทำไม record นั้นๆถึงเป็น missing**
#
# เนื่องจากมีผู้ป่วย 1343 ราย ที่ไม่ทราบเพศในจังหวัดสมุทรสาคร ซึ่งคาดว่าสาเหตุเกิดจากช่วงที่มีการระบาดจำนวนมาก ทำให้การเก็บและบันทึกข้อมูลเร่งด่วน
# หรืออาจเกิดจากการไม่เข้าใจภาษาของชาวเมียนมาร์ทำให้มีข้อมูลบางส่วนยังไม่สมบูรณ์

# %% [markdown]
# # .groupby()
# https://www.kaggle.com/crawford/python-groupby-tutorial#

# %%
data_covid.groupby('nationality') ## จัดกลุ่มค่าที่เหมือนกันไว้ด้วยกัน

# %%
data_covid.groupby('nationality').count()
# Out:
#                 No.  announce_date  Notified date  sex  age  \
# nationality
# Afghanistan       1              1              1    1    1
# Albania           3              3              3    3    3
# American          1              1              1    1    1
# American          1              1              1    1    1
# American Samoa    1              1              1    1    1
# ...             ...            ...            ...  ...  ...
# china             1              1              1    1    1
# deutsch           1              1              1    1    1
# ต่างด้าว         21             21             21   21   21
# ไทยใหญ่           1              1              1    1    1
# ไทใหญ่            1              1              1    1    1
#
#                 province_of_isolation  province_of_onset  district_of_onset  \
# nationality
# Afghanistan                         1                  1                  1
# Albania                             3                  3                  2
# American                            1                  1                  1
# American                            1                  1                  1
# American Samoa                      1                  1                  1
# ...                               ...                ...                ...
# china                               1                  1                  1
# deutsch                             1                  1                  1
# ต่างด้าว                           21                 21                 21
# ไทยใหญ่                             1                  1                  1
# ไทใหญ่                              1                  1                  1
#
#                 risk
# nationality
# Afghanistan        1
# Albania            3
# American           1
# American           1
# American Samoa     1
# ...              ...
# china              1
# deutsch            1
# ต่างด้าว          21
# ไทยใหญ่            1
# ไทใหญ่             1
#
# [97 rows x 9 columns]

# %%
data_covid.groupby('nationality').mean(' ')
# Out:
#                          No.        age
# nationality
# Afghanistan      4347.000000  31.000000
# Albania          2378.333333  40.666667
# American         3863.000000  39.000000
# American         3906.000000  46.000000
# American Samoa  11688.000000  21.000000
# ...                      ...        ...
# china            5754.000000  51.000000
# deutsch          3899.000000  55.000000
# ต่างด้าว         2945.952381  20.000000
# ไทยใหญ่         10380.000000  30.000000
# ไทใหญ่           5984.000000  33.000000
#
# [97 rows x 2 columns]

# %%
data_covid.groupby('nationality').max(' ') ### ทำไมใส่ ' ' แล้วรันได้!!
# Out:
#                   No.   age
# nationality
# Afghanistan      4347  31.0
# Albania          3523  51.0
# American         3863  39.0
# American         3906  46.0
# American Samoa  11688  21.0
# ...               ...   ...
# china            5754  51.0
# deutsch          3899  55.0
# ต่างด้าว         2999  43.0
# ไทยใหญ่         10380  30.0
# ไทใหญ่           5984  33.0
#
# [97 rows x 2 columns]

# %% [markdown]
# ทำ HW7 ด้วย groupby()

# %%
data_covid['sex'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: sex, Length: 12653, dtype: bool

# %%
missing_sex = data_covid[data_covid['sex'].isnull()]
missing_sex
# Out:
#        No. announce_date Notified date  sex  age nationality  \
# 4397  4398      20/12/20           NaN  NaN  NaN       Burma
# 4398  4399      20/12/20           NaN  NaN  NaN       Burma
# 4399  4400      20/12/20           NaN  NaN  NaN       Burma
# 4400  4401      20/12/20           NaN  NaN  NaN       Burma
# 4401  4402      20/12/20           NaN  NaN  NaN       Burma
# ...    ...           ...           ...  ...  ...         ...
# 7692  7693        3/1/21           NaN  NaN  NaN         NaN
# 7693  7694        3/1/21           NaN  NaN  NaN         NaN
# 7694  7695        3/1/21           NaN  NaN  NaN         NaN
# 8395  8396        4/1/21      3/1/2021  NaN  NaN         NaN
# 8544  8545        5/1/21      4/1/2021  NaN  NaN         NaN
#
#      province_of_isolation province_of_onset district_of_onset  \
# 4397             สมุทรสาคร         สมุทรสาคร             เมือง
# 4398             สมุทรสาคร         สมุทรสาคร             เมือง
# 4399             สมุทรสาคร         สมุทรสาคร             เมือง
# 4400             สมุทรสาคร         สมุทรสาคร             เมือง
# 4401             สมุทรสาคร         สมุทรสาคร             เมือง
# ...                    ...               ...               ...
# 7692             สมุทรสาคร               NaN               NaN
# 7693             สมุทรสาคร               NaN               NaN
# 7694             สมุทรสาคร               NaN               NaN
# 8395              จันทบุรี               NaN               NaN
# 8544             สมุทรสาคร         สมุทรสาคร    เมืองสมุทรสาคร
#
#                    risk
# 4397  Cluster สมุทรสาคร
# 4398  Cluster สมุทรสาคร
# 4399  Cluster สมุทรสาคร
# 4400  Cluster สมุทรสาคร
# 4401  Cluster สมุทรสาคร
# ...                 ...
# 7692  Cluster สมุทรสาคร
# 7693  Cluster สมุทรสาคร
# 7694  Cluster สมุทรสาคร
# 8395                NaN
# 8544  Cluster สมุทรสาคร
#
# [1609 rows x 10 columns]

# %%
missing_sex.groupby('nationality').describe()
# Out:
#                 No.                                                    \
#               count         mean         std     min      25%     50%
# nationality
# Burma        1360.0  5127.650735  470.761404  4398.0  4737.75  5099.5
# Cambodia       59.0  6852.779661  274.879853  6544.0  6567.00  7034.0
# Thailand       47.0  7210.148936  509.370497  6268.0  6791.00  7507.0
#
#                                age
#                  75%     max count  mean std   min   25%   50%   75%   max
# nationality
# Burma        5469.25  7076.0   0.0   NaN NaN   NaN   NaN   NaN   NaN   NaN
# Cambodia     7129.50  7161.0   0.0   NaN NaN   NaN   NaN   NaN   NaN   NaN
# Thailand     7537.50  7549.0   1.0  28.0 NaN  28.0  28.0  28.0  28.0  28.0

# %%
missing_sex.groupby('province_of_onset').describe()
# Out:
#                       No.                                                    \
#                     count         mean         std     min      25%     50%
# province_of_onset
# ชลบุรี               18.0  7507.055556    6.637436  7498.0  7502.25  7506.5
# ระยอง                 6.0  6290.000000   49.010203  6268.0  6269.25  6270.5
# สมุทรสาคร          1347.0  5111.783222  447.329257  4398.0  4734.50  5093.0
#
#                                      age                                    \
#                        75%     max count  mean std   min   25%   50%   75%
# province_of_onset
# ชลบุรี             7510.75  7525.0   1.0  28.0 NaN  28.0  28.0  28.0  28.0
# ระยอง              6271.75  6390.0   0.0   NaN NaN   NaN   NaN   NaN   NaN
# สมุทรสาคร          5459.50  8545.0   0.0   NaN NaN   NaN   NaN   NaN   NaN
#
#
#                     max
# province_of_onset
# ชลบุรี             28.0
# ระยอง               NaN
# สมุทรสาคร           NaN

# %%
missing_sex.groupby(['province_of_onset','nationality']).describe() ## groupby หลาย column
# Out:
#                                   No.                                   \
#                                 count         mean         std     min
# province_of_onset nationality
# ชลบุรี            Thailand       18.0  7507.055556    6.637436  7498.0
# ระยอง             Thailand        6.0  6290.000000   49.010203  6268.0
# สมุทรสาคร         Thailand        3.0  6274.000000    1.000000  6273.0
#                   Burma        1343.0  5106.630678  434.592487  4398.0
#
#                                                                   age        \
#                                    25%     50%      75%     max count  mean
# province_of_onset nationality
# ชลบุรี            Thailand     7502.25  7506.5  7510.75  7525.0   1.0  28.0
# ระยอง             Thailand     6269.25  6270.5  6271.75  6390.0   0.0   NaN
# สมุทรสาคร         Thailand     6273.50  6274.0  6274.50  6275.0   0.0   NaN
#                   Burma        4733.50  5091.0  5456.50  6286.0   0.0   NaN
#
#
#                               std   min   25%   50%   75%   max
# province_of_onset nationality
# ชลบุรี            Thailand    NaN  28.0  28.0  28.0  28.0  28.0
# ระยอง             Thailand    NaN   NaN   NaN   NaN   NaN   NaN
# สมุทรสาคร         Thailand    NaN   NaN   NaN   NaN   NaN   NaN
#                   Burma       NaN   NaN   NaN   NaN   NaN   NaN

# %%
misssing_sex_no_burma = missing_sex[missing_sex['nationality']!='Burma']
misssing_sex_no_burma.groupby('risk').describe()
# Out:
#                        No.                                                    \
#                      count         mean         std     min      25%     50%
# risk
# Cluster ชลบุรี        18.0  7507.055556    6.637436  7498.0  7502.25  7506.5
# Cluster ระยอง          7.0  6364.285714  201.569437  6268.0  6269.50  6271.0
# Cluster สมุทรสาคร     81.0  7239.333333  686.721141  6125.0  6275.00  7656.0
# อยู่ระหว่างการสอบสวน  66.0  6835.924242  272.755868  6544.0  6564.25  6746.0
#
#                                         age                                    \
#                           75%     max count  mean std   min   25%   50%   75%
# risk
# Cluster ชลบุรี        7510.75  7525.0   1.0  28.0 NaN  28.0  28.0  28.0  28.0
# Cluster ระยอง         6331.00  6810.0   0.0   NaN NaN   NaN   NaN   NaN   NaN
# Cluster สมุทรสาคร     7676.00  8545.0   0.0   NaN NaN   NaN   NaN   NaN   NaN
# อยู่ระหว่างการสอบสวน  7128.75  7161.0   0.0   NaN NaN   NaN   NaN   NaN   NaN
#
#
#                        max
# risk
# Cluster ชลบุรี        28.0
# Cluster ระยอง          NaN
# Cluster สมุทรสาคร      NaN
# อยู่ระหว่างการสอบสวน   NaN

# %%
missing_sex.groupby('risk').describe()
# Out:
#                          No.                                            \
#                        count         mean         std     min      25%
# risk
# Cluster ชลบุรี          18.0  7507.055556    6.637436  7498.0  7502.25
# Cluster ระยอง            8.0  6453.250000  313.277946  6268.0  6269.75
# Cluster สมุทรสาคร     1438.0  5242.900556  683.533465  4398.0  4757.25
# อยู่ระหว่างการสอบสวน    68.0  6835.220588  272.442728  6544.0  6563.75
#
#                                                 age                        \
#                          50%      75%     max count  mean std   min   25%
# risk
# Cluster ชลบุรี        7506.5  7510.75  7525.0   1.0  28.0 NaN  28.0  28.0
# Cluster ระยอง         6271.5  6495.00  7076.0   0.0   NaN NaN   NaN   NaN
# Cluster สมุทรสาคร     5138.5  5527.75  8545.0   0.0   NaN NaN   NaN   NaN
# อยู่ระหว่างการสอบสวน  6746.0  7128.25  7161.0   0.0   NaN NaN   NaN   NaN
#
#
#                        50%   75%   max
# risk
# Cluster ชลบุรี        28.0  28.0  28.0
# Cluster ระยอง          NaN   NaN   NaN
# Cluster สมุทรสาคร      NaN   NaN   NaN
# อยู่ระหว่างการสอบสวน   NaN   NaN   NaN

# %%
missing_sex[missing_sex['risk']=='Cluster สมุทรสาคร'].groupby('announce_date').count()
# Out:
#                No.  Notified date  sex  age  nationality  \
# announce_date
# 20/12/20       511              0    0    0          511
# 21/12/20       360              0    0    0          360
# 22/12/20       397              0    0    0          397
# 25/12/20        34              0    0    0           34
# 26/12/20        30              0    0    0           30
# 27/12/20        18             18    0    0            0
# 28/12/20        14              0    0    0           14
# 3/1/21          55              0    0    0            0
# 30/12/20         3              0    0    0            1
# 31/12/20        15              0    0    0           15
# 5/1/21           1              1    0    0            0
#
#                province_of_isolation  province_of_onset  district_of_onset  \
# announce_date
# 20/12/20                         511                511                511
# 21/12/20                         360                360                360
# 22/12/20                         397                397                397
# 25/12/20                          34                 34                 34
# 26/12/20                          30                 30                 30
# 27/12/20                          18                  0                  0
# 28/12/20                          14                 14                 14
# 3/1/21                            55                  0                  0
# 30/12/20                           3                  0                  0
# 31/12/20                          15                  0                  0
# 5/1/21                             1                  1                  1
#
#                risk
# announce_date
# 20/12/20        511
# 21/12/20        360
# 22/12/20        397
# 25/12/20         34
# 26/12/20         30
# 27/12/20         18
# 28/12/20         14
# 3/1/21           55
# 30/12/20          3
# 31/12/20         15
# 5/1/21            1

# %% [markdown]
# ## create pandas table
#  ![pandas-dataframe-shadow.png](data:image/png;base64,...)

# %%
records = [{'account':'Jones LLC','Jan':150,'Feb':200,'Mar':140},
           {'account':'Alpha Co','Jan':200,'Feb':210,'Mar':215},
           {'account':'Blue Inc','Jan':50,'Feb':90,'Mar':95}]
records_df = pd.DataFrame(records)
records_df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## Simple Visualization
#
# ![Iris-Versicolor-Kermesina-1.jpg](data:image/jpeg;base64,...)

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.groupby('Name').count()
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa               50          50           50          50
# Iris-versicolor           50          50           50          50
# Iris-virginica            50          50           50          50

# %%
pd.plotting.parallel_coordinates(df, 'Name');

# %%
pd.plotting.scatter_matrix(df);

# %% [markdown]
# ## save table

# %%
announce_date_count = missing_sex[missing_sex['risk']=='Cluster สมุทรสาคร'].groupby('announce_date').count()
announce_date_count
# Out:
#                No.  Notified date  sex  age  nationality  \
# announce_date
# 20/12/20       511              0    0    0          511
# 21/12/20       360              0    0    0          360
# 22/12/20       397              0    0    0          397
# 25/12/20        34              0    0    0           34
# 26/12/20        30              0    0    0           30
# 27/12/20        18             18    0    0            0
# 28/12/20        14              0    0    0           14
# 3/1/21          55              0    0    0            0
# 30/12/20         3              0    0    0            1
# 31/12/20        15              0    0    0           15
# 5/1/21           1              1    0    0            0
#
#                province_of_isolation  province_of_onset  district_of_onset  \
# announce_date
# 20/12/20                         511                511                511
# 21/12/20                         360                360                360
# 22/12/20                         397                397                397
# 25/12/20                          34                 34                 34
# 26/12/20                          30                 30                 30
# 27/12/20                          18                  0                  0
# 28/12/20                          14                 14                 14
# 3/1/21                            55                  0                  0
# 30/12/20                           3                  0                  0
# 31/12/20                          15                  0                  0
# 5/1/21                             1                  1                  1
#
#                risk
# announce_date
# 20/12/20        511
# 21/12/20        360
# 22/12/20        397
# 25/12/20         34
# 26/12/20         30
# 27/12/20         18
# 28/12/20         14
# 3/1/21           55
# 30/12/20          3
# 31/12/20         15
# 5/1/21            1

# %%
announce_date_count.to_csv('announce_date_count.csv')

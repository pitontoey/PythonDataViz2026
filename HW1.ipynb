# %% [markdown]
# <a href="https://colab.research.google.com/github/pitontoey/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# อารีย์ บุตรบุญชู

# %%
print('ID663020579-1')
# Out:
# ID663020579-1
